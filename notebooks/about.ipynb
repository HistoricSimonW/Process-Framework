# %%
from process._about import get_process_model_version, get_app_name, get_app_version

# %%
print(get_process_model_version())
print(get_app_name())
print(get_app_version())
# Out:
# 0.1.dev6+gca184eb
# process
# 0.1.dev5+g2042bb5.d20250814
